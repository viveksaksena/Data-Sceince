# %%
#Pnadas stands for pnel data
#Pandas is open source library of python to do scientic operations on data .
#We call it excel of python 
#As much as work you can do in excel you can do in pandas easily
#In 2008 Mc kinny developed Pnadas
#We can create fast and efficient data frame in padas
#Pandas deal with following three data structure
#1.Series
#Data Frame
#Pannel

# %%
#Series is one dimensional data 
#Series is homogenious data
#Series size is immutable
#Value of data is mutable
#Data Frame is two dimensioal data its a tabular form of a data 
#

# %%
#################Pandas Series##########################

# %%
#Pandas series can be create by the funciton pandas.series
#pandas.Series( data, index, dtype, copy)

# %%
#First we import our important libraries which we use in our program
import numpy as np
import pandas as pd

# %%
pd.Series([10,11,12,13])
# Out:
# 0    10
# 1    11
# 2    12
# 3    13
# dtype: int64

# %%
#We can also give the index names
pd.Series([10,11,12,13],index=['A','B','C','D'])
# Out:
# A    10
# B    11
# C    12
# D    13
# dtype: int64

# %%
#We can also give the data type also
pd.Series([10,11,12,13],index=['A','B','C','D'],dtype=float)
# Out:
# A    10.0
# B    11.0
# C    12.0
# D    13.0
# dtype: float64

# %%
#We can create the series by the use of dictionary 
a = {'Student Name':['Antika','Anju','Manju'],'RollNo':[101,102,103]}
a
# Out:
# {'Student Name': ['Antika', 'Anju', 'Manju'], 'RollNo': [101, 102, 103]}

# %%
a = pd.Series(a)

# %%
a
# Out:
# Student Name    [Antika, Anju, Manju]
# RollNo                [101, 102, 103]
# dtype: object

# %%
type(a)
# Out:
# pandas.core.series.Series

# %%
#we can create a dictionary by scalar
scal_sr = pd.Series(2,index=['A','B','C','D','E'])

# %%
scal_sr
# Out:
# A    2
# B    2
# C    2
# D    2
# E    2
# dtype: int64

# %%
#Accessing the data with postion

# %%
a[0]
# Out:
# ['Antika', 'Anju', 'Manju']

# %%
a[1]
# Out:
# [101, 102, 103]

# %%
#retriving the first three element
a[:1]
# Out:
# Student Name    [Antika, Anju, Manju]
# dtype: object

# %%
#retriving data using index names
a
# Out:
# Student Name    [Antika, Anju, Manju]
# RollNo                [101, 102, 103]
# dtype: object

# %%
a['Student Name']
# Out:
# ['Antika', 'Anju', 'Manju']

# %%
a['RollNo']
# Out:
# [101, 102, 103]

# %%
################################Data Frame #################################################

# %%
# A data frame is two dimensional data is aligned in tabluram form in row and columns

# %%
# We can create data frame by the use of pandas.DataFrame function
#pandas.DataFrame( data, index, columns, copy)

# %%
#A pandas data frame can be create by following 
#1.list
#2.Dictionary
#3.Series
#4.Numpy Ndarray
#5.Another Data frame for example .csv files xlsx files

# %%
#Create a empty data frame

# %%
df = pd.DataFrame()

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
#Create a dataframe from a list 
l = [10,11,12,13,14,'Hello','Hi','Bye']

# %%
dfl = pd.DataFrame(l)

# %%
dfl
# Out:
#        0
# 0     10
# 1     11
# 2     12
# 3     13
# 4     14
# 5  Hello
# 6     Hi
# 7    Bye

# %%
dfl.dtypes
# Out:
# 0    object
# dtype: object

# %%
#create a dataframe by the use of dictionaries

# %%
player = {'Openers':['Sachin','Sehwag','Ganguly'],'Bowler':['Srisant','Balaji','Harbajan']}

# %%
player_df = pd.DataFrame(player)

# %%
player_df
# Out:
#    Openers    Bowler
# 0   Sachin   Srisant
# 1   Sehwag    Balaji
# 2  Ganguly  Harbajan

# %%
#if we want to change indexing name
player_df = pd.DataFrame(player,index=['A','B','C'])

# %%
player_df
# Out:
#    Openers    Bowler
# A   Sachin   Srisant
# B   Sehwag    Balaji
# C  Ganguly  Harbajan

# %%
#create a dataframe from series of dictionaries
d = {'Actor_Name':pd.Series(['Sharukh','Amitabh','AjayDevgan']),
    'Actoress_Name':pd.Series(['Anushka','Aishwarya','Tapsi'])}

# %%
bollywod_df=pd.DataFrame(d)

# %%
bollywod_df
# Out:
#    Actor_Name Actoress_Name
# 0     Sharukh       Anushka
# 1     Amitabh     Aishwarya
# 2  AjayDevgan         Tapsi

# %%
c = {'IPL':pd.Series(['MI','Bangluru','RR','DD']),
    'Capton Name':pd.Series(['Rohit','Kohli','Sanju','ShiR'])}

# %%
print(c)
# Out:
# {'IPL': 0          MI
# 1    Bangluru
# 2          RR
# 3          DD
# dtype: object, 'Capton Name': 0    Rohit
# 1    Kohli
# 2    Sanju
# 3     ShiR
# dtype: object}

# %%
ipl_df = pd.DataFrame(c)

# %%
ipl_df
# Out:
#         IPL Capton Name
# 0        MI       Rohit
# 1  Bangluru       Kohli
# 2        RR       Sanju
# 3        DD        ShiR

# %%
#column Selection
#we will understand it by selecting a column name form the data frame

# %%
bollywod_df['Actor_Name']
# Out:
# 0       Sharukh
# 1       Amitabh
# 2    AjayDevgan
# Name: Actor_Name, dtype: object

# %%
bollywod_df['Actoress_Name']
# Out:
# 0      Anushka
# 1    Aishwarya
# 2        Tapsi
# Name: Actoress_Name, dtype: object

# %%
#we can also use .(dot) operator 
bollywod_df.Actor_Name
# Out:
# 0       Sharukh
# 1       Amitabh
# 2    AjayDevgan
# Name: Actor_Name, dtype: object

# %%
a = pd.Series([10,11,12,13],index=['A','B','C','D'])

# %%
df_a = pd.DataFrame(a,columns=['A'])

# %%
df_a
# Out:
#     A
# A  10
# B  11
# C  12
# D  13

# %%
df_a['A']
# Out:
# A    10
# B    11
# C    12
# D    13
# Name: A, dtype: int64

# %%
df_a['B'] = df_a['A']*10

# %%
df_a
# Out:
#     A    B
# A  10  100
# B  11  110
# C  12  120
# D  13  130

# %%
df_a['C'] = df_a['A']+df_a['B']

# %%
df_a
# Out:
#     A    B    C
# A  10  100  110
# B  11  110  121
# C  12  120  132
# D  13  130  143

# %%
#Adding a row to a DataFrame using the append function
n = pd.DataFrame([[1,2],[3,4]],columns=['A','B'])
n1 = pd.DataFrame([[20,22],[33,41]],columns=['A','B'])

# %%
n
# Out:
#    A  B
# 0  1  2
# 1  3  4

# %%
n1
# Out:
#     A   B
# 0  20  22
# 1  33  41

# %%
n.append(n1)
# Out:
#     A   B
# 0   1   2
# 1   3   4
# 0  20  22
# 1  33  41

# %%
#Adding a row to a DataFrame using the append function
n = pd.DataFrame([[1,2],[3,4]],columns=['A','B'])
n1 = pd.DataFrame([[20,22],[33,41]],columns=['C','D'])

# %%
n.append(n1)
# Out:
#      A    B     C     D
# 0  1.0  2.0   NaN   NaN
# 1  3.0  4.0   NaN   NaN
# 0  NaN  NaN  20.0  22.0
# 1  NaN  NaN  33.0  41.0

# %%
#Adding a row to a DataFrame using the append function
n = pd.DataFrame([[1,2],[3,4]],columns=['A','B'])
n1 = pd.DataFrame([[20,22],[33,41],[100,200]],columns=['A','B'])

# %%
n.append(n1)
# Out:
#      A    B
# 0    1    2
# 1    3    4
# 0   20   22
# 1   33   41
# 2  100  200

# %%
#Adding a row to a DataFrame using the append function
n = pd.DataFrame([[1,2],[3,4],[100,200]],columns=['A','B'])
n1 = pd.DataFrame([[20,22],[33,41]],columns=['A','B'])

# %%
n.append(n1)
# Out:
#      A    B
# 0    1    2
# 1    3    4
# 2  100  200
# 0   20   22
# 1   33   41

# %%
#Deletion of Rows
n
# Out:
#      A    B
# 0    1    2
# 1    3    4
# 2  100  200

# %%
n1
# Out:
#     A   B
# 0  20  22
# 1  33  41

# %%
n1.drop(0)
# Out:
#     A   B
# 1  33  41

# %%
#Create a dataframe from a .csv file

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\VIVEK\\DSP05 online notes'

# %%
os.chdir(r"D:\Github\CardioGoodFitness---Descriptive-Statistics")

# %%
os.getcwd()
# Out:
# 'D:\\Github\\CardioGoodFitness---Descriptive-Statistics'

# %%
os.listdir()
# Out:
# ['.git',
#  'CardioGoodFitness - Descriptive Statistics.ipynb',
#  'CardioGoodFitness.csv',
#  'README.md']

# %%
#we insert data frame by the use of pd.read_csv function 
Cardio_df = pd.read_csv(r"CardioGoodFitness.csv")

# %%
############################Exploratry Data Analysis ###################################

# %% [markdown]
# # Cardio Good Fitness Case Study - Descriptive Statistics
# The market research team at AdRight is assigned the task to identify the profile of the typical customer for each treadmill product offered by CardioGood Fitness. The market research team decides to investigate whether there are differences across the product lines with respect to customer characteristics. The team decides to collect data on individuals who purchased a treadmill at a CardioGoodFitness retail store during the prior three months. The data are stored in the CardioGoodFitness.csv file.
#
# ### The team identifies the following customer variables to study:
#   - product purchased, TM195, TM498, or TM798;
#   - gender;
#   - age, in years;
#   - education, in years;
#   - relationship status, single or partnered;
#   - annual household income ;
#   - average number of times the customer plans to use the treadmill each week;
#   - average number of miles the customer expects to walk/run each week;
#   - and self-rated fitness on an 1-to-5 scale, where 1 is poor shape and 5 is excellent shape.
#
# ### Perform descriptive analytics to create a customer profile for each CardioGood Fitness treadmill product line.

# %%
Cardio_df
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 0     TM195   18    Male         14        Single      3        4   29562
# 1     TM195   19    Male         15        Single      2        3   31836
# 2     TM195   19  Female         14     Partnered      4        3   30699
# 3     TM195   19    Male         12        Single      3        3   32973
# 4     TM195   20    Male         13     Partnered      4        2   35247
# ..      ...  ...     ...        ...           ...    ...      ...     ...
# 175   TM798   40    Male         21        Single      6        5   83416
# 176   TM798   42    Male         18        Single      5        4   89641
# 177   TM798   45    Male         16        Single      5        5   90886
# 178   TM798   47    Male         18     Partnered      4        5  104581
# 179   TM798   48    Male         18     Partnered      4        5   95508
#
#      Miles
# 0      112
# 1       75
# 2       66
# 3       85
# 4       47
# ...

# %%
#Head function show first 5 rows
Cardio_df.head()
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 0   TM195   18    Male         14        Single      3        4   29562    112
# 1   TM195   19    Male         15        Single      2        3   31836     75
# 2   TM195   19  Female         14     Partnered      4        3   30699     66
# 3   TM195   19    Male         12        Single      3        3   32973     85
# 4   TM195   20    Male         13     Partnered      4        2   35247     47

# %%
#we can show first 10 row by the passing argument in head function
Cardio_df.head(10)
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 0   TM195   18    Male         14        Single      3        4   29562    112
# 1   TM195   19    Male         15        Single      2        3   31836     75
# 2   TM195   19  Female         14     Partnered      4        3   30699     66
# 3   TM195   19    Male         12        Single      3        3   32973     85
# 4   TM195   20    Male         13     Partnered      4        2   35247     47
# 5   TM195   20  Female         14     Partnered      3        3   32973     66
# 6   TM195   21  Female         14     Partnered      3        3   35247     75
# 7   TM195   21    Male         13        Single      3        3   32973     85
# 8   TM195   21    Male         15        Single      5        4   35247    141
# 9   TM195   21  Female         15     Partnered      2        3   37521     85

# %%
#we can show last 5 row by the tail function
Cardio_df.tail()
# Out:
#     Product  Age Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 175   TM798   40   Male         21        Single      6        5   83416
# 176   TM798   42   Male         18        Single      5        4   89641
# 177   TM798   45   Male         16        Single      5        5   90886
# 178   TM798   47   Male         18     Partnered      4        5  104581
# 179   TM798   48   Male         18     Partnered      4        5   95508
#
#      Miles
# 175    200
# 176    200
# 177    160
# 178    120
# 179    180

# %%
#we can show last 10 row by the give argument in tail function
Cardio_df.tail(10)
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 170   TM798   31    Male         16     Partnered      6        5   89641
# 171   TM798   33  Female         18     Partnered      4        5   95866
# 172   TM798   34    Male         16        Single      5        5   92131
# 173   TM798   35    Male         16     Partnered      4        5   92131
# 174   TM798   38    Male         18     Partnered      5        5  104581
# 175   TM798   40    Male         21        Single      6        5   83416
# 176   TM798   42    Male         18        Single      5        4   89641
# 177   TM798   45    Male         16        Single      5        5   90886
# 178   TM798   47    Male         18     Partnered      4        5  104581
# 179   TM798   48    Male         18     Partnered      4        5   95508
#
#      Miles
# 170    260
# 171    200
# 172    150
# 173    360
# 174    150
# 175    200
# 176    200
# 177    160
# 178    120
# 179    180

# %%
#we can chaeck datatype by dtypes function
Cardio_df.dtypes
# Out:
# Product          object
# Age               int64
# Gender           object
# Education         int64
# MaritalStatus    object
# Usage             int64
# Fitness           int64
# Income            int64
# Miles             int64
# dtype: object

# %%
#we can check columns name by the use columns function
Cardio_df.columns
# Out:
# Index(['Product', 'Age', 'Gender', 'Education', 'MaritalStatus', 'Usage',
#        'Fitness', 'Income', 'Miles'],
#       dtype='object')

# %%
#we can check summary the use of descibe function

# %%
Cardio_df['Age'].describe()
# Out:
# count    180.000000
# mean      28.788889
# std        6.943498
# min       18.000000
# 25%       24.000000
# 50%       26.000000
# 75%       33.000000
# max       50.000000
# Name: Age, dtype: float64

# %%
Cardio_df['Age'].std()
# Out:
# 6.943498135399795

# %%
Cardio_df['Age'].count()
# Out:
# 180

# %%
Cardio_df['Age'].mean()
# Out:
# 28.788888888888888

# %%
Cardio_df['Income'].sum()
# Out:
# 9669524

# %%
Cardio_df['Income'].describe()
# Out:
# count       180.000000
# mean      53719.577778
# std       16506.684226
# min       29562.000000
# 25%       44058.750000
# 50%       50596.500000
# 75%       58668.000000
# max      104581.000000
# Name: Income, dtype: float64

# %%
Cardio_df['Income'].mean()
# Out:
# 53719.57777777778

# %%
Cardio_df['Income'].count()
# Out:
# 180

# %%
#Pandas 26-02-2021

# %% [markdown]
# ### Python Pandas - Iteration

# %%
Cardio_df
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 0     TM195   18    Male         14        Single      3        4   29562
# 1     TM195   19    Male         15        Single      2        3   31836
# 2     TM195   19  Female         14     Partnered      4        3   30699
# 3     TM195   19    Male         12        Single      3        3   32973
# 4     TM195   20    Male         13     Partnered      4        2   35247
# ..      ...  ...     ...        ...           ...    ...      ...     ...
# 175   TM798   40    Male         21        Single      6        5   83416
# 176   TM798   42    Male         18        Single      5        4   89641
# 177   TM798   45    Male         16        Single      5        5   90886
# 178   TM798   47    Male         18     Partnered      4        5  104581
# 179   TM798   48    Male         18     Partnered      4        5   95508
#
#      Miles
# 0      112
# 1       75
# 2       66
# 3       85
# 4       47
# ...

# %%
for col in Cardio_df:
    print(col)
# Out:
# Product
# Age
# Gender
# Education
# MaritalStatus
# Usage
# Fitness
# Income
# Miles

# %% [markdown]
# To iterate over the rows of the DataFrame, we can use the following functions −
#
# iteritems() − to iterate over the (key,value) pairs
#
# iterrows() − iterate over the rows as (index,series) pairs
#
# itertuples() − iterate over the rows as namedtuples

# %%
for key, value in Cardio_df.iteritems():
    print(f"{key} {value}")
# Out:
# Product 0      TM195
# 1      TM195
# 2      TM195
# 3      TM195
# 4      TM195
#        ...
# 175    TM798
# 176    TM798
# 177    TM798
# 178    TM798
# 179    TM798
# Name: Product, Length: 180, dtype: object
# Age 0      18
# 1      19
# 2      19
# 3      19
# 4      20
#        ..
# 175    40
# 176    42
# 177    45
# 178    47
# 179    48
# Name: Age, Length: 180, dtype: int64
# Gender 0        Male
# 1        Male
# 2      Female
# 3        Male
# 4        Male
#         ...
# 175      Male
# 176      Male
# 177      Male
# 178      Male
# 179      Male
# Name: Gender, Length: 180, dtype: object
# Education 0      14
# 1      15
# 2      14
# 3      12
# 4      13
#        ..
# 175    21
# 176    18
# 177    16
# 178    18
# 179    18
# Name: Education, Length: 180, dtype: int64
# MaritalStatus 0         Single
# 1         Single
# 2      Partnered
# 3         Single
# 4      Partnered
#          ...
# 175       Single
# 176       Single
# 177       Single
# ...

# %%
for index, value in Cardio_df.iterrows():
    print(f"{index} {value}")
# Out:
# 0 Product           TM195
# Age                  18
# Gender             Male
# Education            14
# MaritalStatus    Single
# Usage                 3
# Fitness               4
# Income            29562
# Miles               112
# Name: 0, dtype: object
# 1 Product           TM195
# Age                  19
# Gender             Male
# Education            15
# MaritalStatus    Single
# Usage                 2
# Fitness               3
# Income            31836
# Miles                75
# Name: 1, dtype: object
# 2 Product              TM195
# Age                     19
# Gender              Female
# Education               14
# MaritalStatus    Partnered
# Usage                    4
# Fitness                  3
# Income               30699
# Miles                   66
# Name: 2, dtype: object
# 3 Product           TM195
# Age                  19
# Gender             Male
# Education            12
# MaritalStatus    Single
# Usage                 3
# Fitness               3
# ...

# %% [markdown]
# Python Pandas - Sorting

# %%
Cardio_df['Age']
# Out:
# 0      18
# 1      19
# 2      19
# 3      19
# 4      20
#        ..
# 175    40
# 176    42
# 177    45
# 178    47
# 179    48
# Name: Age, Length: 180, dtype: int64

# %%
Cardio_df['Age'].sort_index()
# Out:
# 0      18
# 1      19
# 2      19
# 3      19
# 4      20
#        ..
# 175    40
# 176    42
# 177    45
# 178    47
# 179    48
# Name: Age, Length: 180, dtype: int64

# %%
Cardio_df['Age'].sort_index(ascending=False)
# Out:
# 179    48
# 178    47
# 177    45
# 176    42
# 175    40
#        ..
# 4      20
# 3      19
# 2      19
# 1      19
# 0      18
# Name: Age, Length: 180, dtype: int64

# %%
Cardio_df.sort_index(axis=1)
# Out:
#      Age  Education  Fitness  Gender  Income MaritalStatus  Miles Product  \
# 0     18         14        4    Male   29562        Single    112   TM195
# 1     19         15        3    Male   31836        Single     75   TM195
# 2     19         14        3  Female   30699     Partnered     66   TM195
# 3     19         12        3    Male   32973        Single     85   TM195
# 4     20         13        2    Male   35247     Partnered     47   TM195
# ..   ...        ...      ...     ...     ...           ...    ...     ...
# 175   40         21        5    Male   83416        Single    200   TM798
# 176   42         18        4    Male   89641        Single    200   TM798
# 177   45         16        5    Male   90886        Single    160   TM798
# 178   47         18        5    Male  104581     Partnered    120   TM798
# 179   48         18        5    Male   95508     Partnered    180   TM798
#
#      Usage
# 0        3
# 1        2
# 2        4
# 3        3
# 4        4
# ...

# %%
Cardio_df['Gender'].str.lower()
# Out:
# 0        male
# 1        male
# 2      female
# 3        male
# 4        male
#         ...
# 175      male
# 176      male
# 177      male
# 178      male
# 179      male
# Name: Gender, Length: 180, dtype: object

# %%
Cardio_df['Gender'].str.upper()
# Out:
# 0        MALE
# 1        MALE
# 2      FEMALE
# 3        MALE
# 4        MALE
#         ...
# 175      MALE
# 176      MALE
# 177      MALE
# 178      MALE
# 179      MALE
# Name: Gender, Length: 180, dtype: object
